# %%
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------  3.9/4.0 MB 39.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 30.1 MB/s  0:00:00
# ...
# WARNING: Ignoring invalid distribution ~orch (C:\Users\gabri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\gabri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\gabri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Users\gabri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages)
#
# ...

# %%
import pandas as pd

# %%
url = 'https://www.contextures.com/xlsampledata01.html

# %%
df = pd.DataFrame()

# %%
tabela = pd.read_html(url)
